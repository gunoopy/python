# %% [markdown]
# # Python Version Update
# > Google Colab Python Version `3.7.11` -> `3.8.11` update
#
# <br/>
# * Code
# ```
# !wget https://www.python.org/ftp/python/3.8.11/Python-3.8.11.tgz
# !tar xvfz Python-3.8.11.tgz
# !Python-3.8.11/configure
# !make
# !sudo make install
# ```
# <br/>
# <br/>

# %%
# clear output function
from google.colab import output

print('hello colab')
output.clear()

# %%
# !python --version
# Out:
# Python 3.7.11

# %%
# %%time

# !wget https://www.python.org/ftp/python/3.8.11/Python-3.8.11.tgz
# !tar xvfz Python-3.8.11.tgz
# !Python-3.8.11/configure
# !make
# !sudo make install

output.clear()
# Out:
# CPU times: user 3.77 s, sys: 526 ms, total: 4.3 s
# Wall time: 4min 20s

# %%
# !python --version
# Out:
# Python 3.8.11
